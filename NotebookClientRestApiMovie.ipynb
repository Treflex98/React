# %%
import pandas as pd
import requests
from datetime import datetime, date

# %%
limit = 1500
dfMovies = pd.read_json(f'http://localhost:8000/movies?limit={limit}')
dfMovies.set_index('id', inplace=True)
dfMovies
# Out:
#                                                       title  year  duration
# id
# 5257                                              Excuse Me  1915      50.0
# 6366                                     Anton the Terrible  1916      50.0
# 8351                        The Mysterious Mrs. Musslewhite  1917      50.0
# 8384                                           On the Level  1917      50.0
# 8642                                       The Sunset Trail  1917      50.0
# ...                                                     ...   ...       ...
# 11744604                                  Guardians of Life  2020       3.0
# 11833768                    Neil Cicierega: Wow Wow (Audio)  2017       3.0
# 11885402           Dan Aykroyd and Tom Hanks: City of Crime  1987       NaN
# 11911992                           Bleu de Chanel: The Film  2018       1.0
# 12771922  Neil Cicierega: Vivid Memories Turn to Fantasi...  2014       3.0
#
# [1441 rows x 3 columns]

# %%
type(dfMovies)
# Out:
# pandas.core.frame.DataFrame

# %%
dfStatsMovieByYear = pd.read_json('http://localhost:8000/movies/count_by_year')
dfStatsMovieByYear.columns=['year', 'movie_count']
#dfStatsMovieByYear.set_index('year', inplace=True)
dfStatsMovieByYear
# Out:
#      year  movie_count
# 0    1915            1
# 1    1916            1
# 2    1917            7
# 3    1918           10
# 4    1919           10
# ..    ...          ...
# 101  2016           15
# 102  2017           22
# 103  2018           20
# 104  2019           28
# 105  2020            6
#
# [106 rows x 2 columns]

# %%
# le résultat n'est pas fameux
dfStatsMovieByDirector = pd.read_json('http://localhost:8000/stars/stats_movie_by_director')
dfStatsMovieByDirector
# Out:
#                                                      0   1
# 0    {'id': 33, 'birthdate': '1899-08-13', 'name': ...  60
# 1    {'id': 41, 'birthdate': None, 'name': 'Akira K...   1
# 2    {'id': 78, 'birthdate': '1907-05-26', 'name': ...   1
# 3    {'id': 95, 'birthdate': '1935-01-01', 'name': ...   3
# 4    {'id': 116, 'birthdate': '1954-08-16', 'name':...  14
# ..                                                 ...  ..
# 609  {'id': 5170520, 'birthdate': None, 'name': 'Ch...   1
# 610  {'id': 5638280, 'birthdate': None, 'name': 'Mo...   1
# 611  {'id': 8477405, 'birthdate': None, 'name': 'Cl...   1
# 612  {'id': 9497376, 'birthdate': None, 'name': 'Pa...   1
# 613  {'id': 9565029, 'birthdate': None, 'name': 'Je...   1
#
# [614 rows x 2 columns]

# %%
response = requests.get('http://localhost:8000/stars/stats_movie_by_director')
response
# Out:
# <Response [200]>

# %%
if response.status_code == 200:
    print('Response OK')
else:
    print('Error', response.status_code, response.json(), sep=', ')
# Out:
# Response OK

# %%
data_json = response.json()
data_json
# Out:
# [[{'id': 33, 'birthdate': '1899-08-13', 'name': 'Alfred Hitchcock'}, 60],
#  [{'id': 41, 'birthdate': None, 'name': 'Akira Kurosawa'}, 1],
#  [{'id': 78, 'birthdate': '1907-05-26', 'name': 'John Wayne'}, 1],
#  [{'id': 95, 'birthdate': '1935-01-01', 'name': 'Woody Allen'}, 3],
#  [{'id': 116, 'birthdate': '1954-08-16', 'name': 'James Cameron'}, 14],
#  [{'id': 125, 'birthdate': '1930-08-25', 'name': 'Sean Connery'}, 1],
#  [{'id': 142, 'birthdate': '1930-05-31', 'name': 'Clint Eastwood'}, 39],
#  [{'id': 158, 'birthdate': '1956-07-09', 'name': 'Tom Hanks'}, 2],
#  [{'id': 165, 'birthdate': '1954-01-01', 'name': 'Ron Howard'}, 6],
#  [{'id': 184, 'birthdate': '1944-01-01', 'name': 'George Lucas'}, 3],
#  [{'id': 204, 'birthdate': '1981-06-09', 'name': 'Natalie Portman'}, 2],
#  [{'id': 212, 'birthdate': '1961-01-01', 'name': 'Meg Ryan'}, 1],
#  [{'id': 217, 'birthdate': '1942-11-17', 'name': 'Martin Scorsese'}, 48],
#  [{'id': 229, 'birthdate': '1946-12-18', 'name': 'Steven Spielberg'}, 41],
#  [{'id': 230, 'birthdate': '1946-07-06', 'name': 'Sylvester Stallone'}, 8],
#  [{'id': 231, 'birthdate': '1946-01-01', 'name': 'Oliver Stone'}, 1],
#  [{'id': 233, 'birthdate': '1963-03-27', 'name': 'Quentin Tarantino'}, 14],
#  [{'id': 241, 'birthdate': '1960-10-18', 'name': 'Jean-Claude Van Damme'}, 2],
#  [{'id': 247, 'birthdate': '1946-09-22', 'name': 'John Woo'}, 34],
#  [{'id': 265, 'birthdate': '1925-01-01', 'name': 'Robert Altman'}, 1],
#  [{'id': 269, 'birthdate': None, 'name': 'Jean-Jacques Annaud'}, 1],
#  [{'id': 276, 'birthdate': None, 'name': 'Sean Astin'}, 1],
#  [{'id': 277, 'birthdate': '1923-01-01', 'name': 'Richard Attenborough'}, 1],
#  [{'id': 338, 'birthdate': '1939-01-01', 'name': 'Francis Ford Coppola'}, 2],
#  [{'id': 341, 'birthdate': None, 'name': 'Michael Crichton'}, 1],
#  [{'id': 361, 'birthdate': '1940-09-11', 'name': 'Brian De Palma'}, 38],
#  [{'id': 386, 'birthdate': None, 'name': 'Roland Emmerich'}, 2],
#  [{'id': 406, 'birthdate': None, 'name': 'John Ford'}, 20],
#  [{'id': 416, 'birthdate': None, 'name': 'Terry Gilliam'}, 1],
#  [{'id': 428, 'birthdate': None, 'name': 'D.W. Griffith'}, 1],
#  [{'id': 484, 'birthdate': '1950-01-01', 'name': 'John Landis'}, 4],
#  [{'id': 487, 'birthdate': None, 'name': 'Ang Lee'}, 2],
#  [{'id': 490, 'birthdate': '1957-01-01', 'name': 'Spike Lee'}, 1],
#  [{'id': 520, 'birthdate': None, 'name': 'Michael Mann'}, 1],
#  [{'id': 583, 'birthdate': None, 'name': 'Wolfgang Petersen'}, 2],
#  [{'id': 591, 'birthdate': '1933-01-01', 'name': 'Roman Polanski'}, 1],
#  [{'id': 600, 'birthdate': '1959-10-23', 'name': 'Sam Raimi'}, 31],
#  [{'id': 602, 'birthdate': '1936-01-01', 'name': 'Robert Redford'}, 2],
#  [{'id': 631, 'birthdate': '1937-11-30', 'name': 'Ridley Scott'}, 35],
#  [{'id': 682, 'birthdate': None, 'name': 'Paul Verhoeven'}, 1],
#  [{'id': 709, 'birthdate': None, 'name': 'Robert Zemeckis'}, 4],
#  [{'id': 729, 'birthdate': None, 'name': 'Casey Affleck'}, 1],
#  [{'id': 736, 'birthdate': None, 'name': 'Robert Aldrich'}, 1],
#  [{'id': 750, 'birthdate': None, 'name': 'Jon Amiel'}, 1],
#  [{'id': 759, 'birthdate': None, 'name': 'Paul Thomas Anderson'}, 3],
#  [{'id': 766, 'birthdate': None, 'name': 'Theodoros Angelopoulos'}, 1],
#  [{'id': 774, 'birthdate': None, 'name': 'Michelangelo Antonioni'}, 1],
#  [{'id': 776, 'birthdate': None, 'name': 'Michael Apted'}, 1],
#  [{'id': 791, 'birthdate': None, 'name': 'Jack Arnold'}, 2],
#  [{'id': 801, 'birthdate': None, 'name': 'Olivier Assayas'}, 1],
#  [{'id': 814, 'birthdate': None, 'name': 'John G. Avildsen'}, 3],
#  [{'id': 860, 'birthdate': '1938-01-01', 'name': 'Paul Bartel'}, 2],
#  [{'id': 881, 'birthdate': None, 'name': 'Michael Bay'}, 3],
#  [{'id': 894, 'birthdate': None, 'name': 'Jean-Jacques Beineix'}, 1],
#  [{'id': 907, 'birthdate': '1938-01-01', 'name': 'Richard Benjamin'}, 3],
#  [{'id': 915, 'birthdate': None, 'name': 'Bruce Beresford'}, 1],
#  [{'id': 916, 'birthdate': '1964-01-01', 'name': 'Peter Berg'}, 2],
#  [{'id': 941, 'birthdate': '1951-01-01', 'name': 'Kathryn Bigelow'}, 1],
#  [{'id': 953, 'birthdate': None, 'name': 'Peter Bogdanovich'}, 1],
#  [{'id': 958, 'birthdate': '1933-01-01', 'name': 'John Boorman'}, 1],
#  [{'id': 965, 'birthdate': '1956-10-20', 'name': 'Danny Boyle'}, 18],
#  [{'id': 983, 'birthdate': '1947-01-01', 'name': 'Albert Brooks'}, 1],
#  [{'id': 1047, 'birthdate': None, 'name': 'Michael Cimino'}, 1],
#  [{'id': 1053, 'birthdate': '1957-09-21', 'name': 'Ethan Coen'}, 12],
#  [{'id': 1054, 'birthdate': '1954-11-29', 'name': 'Joel Coen'}, 11],
#  [{'id': 1081, 'birthdate': None, 'name': 'Cameron Crowe'}, 1],
#  [{'id': 1102, 'birthdate': '1946-01-01', 'name': 'Joe Dante'}, 3],
#  [{'id': 1104, 'birthdate': None, 'name': 'Frank Darabont'}, 1],
#  [{'id': 1112, 'birthdate': None, 'name': 'Andrew Davis'}, 2],
#  [{'id': 1120, 'birthdate': None, 'name': 'Vittorio De Sica'}, 1],
#  [{'id': 1124, 'birthdate': '1881-01-01', 'name': 'Cecil B. DeMille'}, 1],
#  [{'id': 1129, 'birthdate': None, 'name': 'Jonathan Demme'}, 2],
#  [{'id': 1149, 'birthdate': None, 'name': 'Richard Donner'}, 3],
#  [{'id': 1188, 'birthdate': None, 'name': 'Nora Ephron'}, 2],
#  [{'id': 1241, 'birthdate': None, 'name': 'Stephen Frears'}, 1],
#  [{'id': 1274, 'birthdate': None, 'name': 'Paul Michael Glaser'}, 1],
#  [{'id': 1317, 'birthdate': '1959-01-01', 'name': 'Renny Harlin'}, 2],
#  [{'id': 1328, 'birthdate': None, 'name': 'Howard Hawks'}, 5],
#  [{'id': 1338, 'birthdate': None, 'name': 'Brian Helgeland'}, 1],
#  [{'id': 1353, 'birthdate': None, 'name': 'Walter Hill'}, 2],
#  [{'id': 1379, 'birthdate': '1906-01-01', 'name': 'John Huston'}, 3],
#  [{'id': 1382, 'birthdate': None, 'name': 'Peter Hyams'}, 7],
#  [{'id': 1392, 'birthdate': '1961-10-31', 'name': 'Peter Jackson'}, 19],
#  [{'id': 1466, 'birthdate': '1929-01-01', 'name': 'Sergio Leone'}, 3],
#  [{'id': 1469, 'birthdate': '1942-01-01', 'name': 'Barry Levinson'}, 1],
#  [{'id': 1486, 'birthdate': None, 'name': 'Sidney Lumet'}, 6],
#  [{'id': 1508, 'birthdate': None, 'name': 'Penny Marshall'}, 3],
#  [{'id': 1532, 'birthdate': None, 'name': 'John McTiernan'}, 4],
#  [{'id': 1566, 'birthdate': None, 'name': 'Mike Nichols'}, 3],
#  [{'id': 1587, 'birthdate': None, 'name': 'Alan J. Pakula'}, 2],
#  [{'id': 1591, 'birthdate': None, 'name': 'Bruce Paltrow'}, 1],
#  [{'id': 1603, 'birthdate': '1925-01-01', 'name': 'Sam Peckinpah'}, 2],
#  [{'id': 1618, 'birthdate': '1974-10-28', 'name': 'Joaquin Phoenix'}, 2],
#  [{'id': 1628, 'birthdate': '1934-01-01', 'name': 'Sydney Pollack'}, 2],
#  [{'id': 1639, 'birthdate': None, 'name': 'Alex Proyas'}, 1],
#  [{'id': 1675, 'birthdate': '1968-01-01', 'name': 'Robert Rodriguez'}, 5],
#  [{'id': 1681, 'birthdate': '1940-01-01', 'name': 'George A. Romero'}, 1],
#  [{'id': 1708, 'birthdate': None, 'name': 'Joel Schumacher'}, 2],
#  [{'id': 1716, 'birthdate': None, 'name': 'Tony Scott'}, 2],
#  [{'id': 1756, 'birthdate': None, 'name': 'Barry Sonnenfeld'}, 4],
#  [{'id': 1814, 'birthdate': '1952-01-01', 'name': 'Gus Van Sant'}, 3],
#  [{'id': 1837, 'birthdate': None, 'name': 'Peter Weir'}, 2],
#  [{'id': 1857, 'birthdate': '1945-01-01', 'name': 'Henry Winkler'}, 1],
#  [{'id': 2031, 'birthdate': None, 'name': 'Michael Curtiz'}, 3],
#  [{'id': 2118, 'birthdate': None, 'name': 'Alan Hale'}, 1],
#  [{'id': 2137, 'birthdate': None, 'name': 'Arthur Hiller'}, 1],
#  [{'id': 2175, 'birthdate': None, 'name': 'Ken Annakin'}, 1],
#  [{'id': 2179, 'birthdate': None, 'name': 'George Archainbaud'}, 1],
#  [{'id': 2191, 'birthdate': None, 'name': 'Jacques Audiard'}, 1],
#  [{'id': 2233, 'birthdate': '1885-01-01', 'name': 'Erich von Stroheim'}, 1],
#  [{'id': 2718, 'birthdate': None, 'name': 'Brian Koppelman'}, 1],
#  [{'id': 3152, 'birthdate': None, 'name': 'Sean McGinly'}, 1],
#  [{'id': 3418, 'birthdate': '1949-01-01', 'name': 'Rob Cohen'}, 4],
#  [{'id': 3422, 'birthdate': None, 'name': 'Louis King'}, 1],
#  [{'id': 3423, 'birthdate': None, 'name': 'Peter MacDonald'}, 2],
#  [{'id': 3506, 'birthdate': None, 'name': 'James Mangold'}, 2],
#  [{'id': 3593, 'birthdate': None, 'name': 'Fred Zinnemann'}, 1],
#  [{'id': 3977, 'birthdate': None, 'name': 'Gary Rydstrom'}, 1],
#  [{'id': 4303, 'birthdate': '1963-01-01', 'name': 'Gavin Hood'}, 1],
#  [{'id': 4851, 'birthdate': '1974-04-28', 'name': 'Penélope Cruz'}, 3],
#  [{'id': 4874, 'birthdate': '1967-07-18', 'name': 'Vin Diesel'}, 4],
#  [{'id': 5069, 'birthdate': None, 'name': 'Spike Jonze'}, 1],
#  [{'id': 5124, 'birthdate': None, 'name': 'John Lasseter'}, 3],
#  [{'id': 5190, 'birthdate': None, 'name': 'Garry Marshall'}, 1],
#  [{'id': 5222, 'birthdate': None, 'name': 'Sam Mendes'}, 3],
#  [{'id': 5295, 'birthdate': '1969-01-01', 'name': 'Trey Parker'}, 1],
#  [{'id': 5363, 'birthdate': None, 'name': 'Guy Ritchie'}, 1],
#  [{'id': 5366, 'birthdate': None, 'name': 'Jay Roach'}, 1],
#  [{'id': 5421, 'birthdate': None, 'name': 'Ron Shelton'}, 1],
#  [{'id': 5563, 'birthdate': None, 'name': 'Irwin Winkler'}, 1],
#  [{'id': 6276, 'birthdate': None, 'name': 'Victor Schertzinger'}, 1],
#  [{'id': 6615, 'birthdate': None, 'name': 'Mauro Bolognini'}, 1],
#  [{'id': 6625, 'birthdate': None, 'name': 'Steve Barron'}, 2],
#  [{'id': 6854, 'birthdate': None, 'name': 'Roger Spottiswoode'}, 4],
#  [{'id': 6943, 'birthdate': None, 'name': 'Charles Lamont'}, 1],
#  [{'id': 7082, 'birthdate': None, 'name': 'John Stockwell'}, 1],
#  [{'id': 7139, 'birthdate': None, 'name': 'Hark Tsui'}, 2],
#  [{'id': 9190, 'birthdate': '1966-01-01', 'name': 'J.J. Abrams'}, 2],
#  [{'id': 15359, 'birthdate': None, 'name': 'Fatih Akin'}, 1],
#  [{'id': 20522, 'birthdate': None, 'name': 'Fred Allen'}, 1],
#  [{'id': 20765, 'birthdate': None, 'name': 'Lewis Allen'}, 1],
#  [{'id': 25978, 'birthdate': None, 'name': 'Allison Anders'}, 1],
#  [{'id': 32925, 'birthdate': None, 'name': 'Shinji Aramaki'}, 1],
#  [{'id': 33420, 'birthdate': None, 'name': 'Renzo Arbore'}, 1],
#  [{'id': 36582, 'birthdate': None, 'name': 'Newt Arnold'}, 1],
#  [{'id': 41678, 'birthdate': None, 'name': 'John H. Auer'}, 1],
#  [{'id': 41932, 'birthdate': None, 'name': 'Mark Rydell'}, 2],
#  [{'id': 43214, 'birthdate': None, 'name': 'Meiert Avis'}, 2],
#  [{'id': 43742, 'birthdate': None, 'name': 'David Ayer'}, 5],
#  [{'id': 44960, 'birthdate': None, 'name': 'E.J. Babille'}, 1],
#  [{'id': 46082, 'birthdate': None, 'name': 'Clarence G. Badger'}, 1],
#  [{'id': 49592, 'birthdate': None, 'name': 'Marius Balchunas'}, 1],
#  [{'id': 50846, 'birthdate': None, 'name': 'Hugo Ballin'}, 1],
#  [{'id': 51643, 'birthdate': '1967-01-01', 'name': 'Tony Bancroft'}, 1],
#  [{'id': 52944, 'birthdate': None, 'name': 'Jack Baran'}, 1],
#  [{'id': 53228, 'birthdate': None, 'name': 'Ernie Barbarash'}, 3],
#  [{'id': 59106, 'birthdate': None, 'name': 'Charles Barton'}, 1],
#  [{'id': 64600, 'birthdate': None, 'name': 'Harry Beaumont'}, 1],
#  [{'id': 65471, 'birthdate': None, 'name': 'Josh Becker'}, 6],
#  [{'id': 65753, 'birthdate': None, 'name': 'Arthur J. Beckhard'}, 1],
#  [{'id': 66247, 'birthdate': None, 'name': 'Ford Beebe'}, 1],
#  [{'id': 72354, 'birthdate': None, 'name': 'Djamel Bensalah'}, 1],
#  [{'id': 74426, 'birthdate': None, 'name': 'Bibo Bergeron'}, 2],
#  [{'id': 82802, 'birthdate': None, 'name': 'Mike Binder'}, 1],
#  [{'id': 83348, 'birthdate': None, 'name': 'Brad Bird'}, 1],
#  [{'id': 86431, 'birthdate': None, 'name': 'Aaron Blaise'}, 1],
#  [{'id': 89502, 'birthdate': None, 'name': 'Albert Pyun'}, 1],
#  [{'id': 89777, 'birthdate': None, 'name': 'Hans-Christoph Blumenberg'}, 1],
#  [{'id': 91575, 'birthdate': '1919-01-01', 'name': 'Paul Bogart'}, 1],
#  [{'id': 94435, 'birthdate': '1969-09-14', 'name': 'Bong Joon Ho'}, 12],
#  [{'id': 102908, 'birthdate': None, 'name': 'Robert N. Bradbury'}, 13],
#  [{'id': 102929, 'birthdate': None, 'name': 'Reb Braddock'}, 1],
#  [{'id': 104193, 'birthdate': None, 'name': 'Marco Brambilla'}, 1],
#  [{'id': 107543, 'birthdate': None, 'name': 'Herbert Brenon'}, 3],
#  [{'id': 109359, 'birthdate': '1962-01-01', 'name': 'Steven Brill'}, 1],
#  [{'id': 112218, 'birthdate': None, 'name': 'Richard Brooks'}, 1],
#  [{'id': 116497, 'birthdate': None, 'name': 'John Bruno'}, 1],
#  [{'id': 121789, 'birthdate': None, 'name': 'Martyn Burke'}, 1],
#  [{'id': 123009, 'birthdate': '1963-01-01', 'name': 'Jeff Burr'}, 1],
#  [{'id': 123285, 'birthdate': None, 'name': 'Ken Burrows'}, 1],
#  [{'id': 124877, 'birthdate': '1894-01-01', 'name': 'David Butler'}, 1],
#  [{'id': 127511, 'birthdate': None, 'name': 'Christy Cabanne'}, 1],
#  [{'id': 130549, 'birthdate': None, 'name': 'Marty Callner'}, 1],
#  [{'id': 131625, 'birthdate': None, 'name': 'John Cameron'}, 1],
#  [{'id': 132709, 'birthdate': None, 'name': 'Martin Campbell'}, 2],
#  [{'id': 132720, 'birthdate': None, 'name': 'Maurice Campbell'}, 1],
#  [{'id': 132926, 'birthdate': None, 'name': 'Webster Campbell'}, 1],
#  [{'id': 134176, 'birthdate': None, 'name': 'Danny Cannon'}, 1],
#  [{'id': 136021, 'birthdate': None, 'name': 'Leos Carax'}, 1],
#  [{'id': 141033, 'birthdate': None, 'name': 'Willard Carroll'}, 1],
#  [{'id': 142286, 'birthdate': None, 'name': 'D.J. Caruso'}, 1],
#  [{'id': 142340, 'birthdate': None, 'name': 'Robert Caruso'}, 1],
#  [{'id': 142587, 'birthdate': None, 'name': 'Steve Carver'}, 1],
#  [{'id': 152831, 'birthdate': None, 'name': 'Mehdi Charef'}, 1],
#  [{'id': 153266, 'birthdate': None, 'name': 'André Charlot'}, 1],
#  [{'id': 154819, 'birthdate': None, 'name': 'Jeremiah S. Chechik'}, 1],
#  [{'id': 156434, 'birthdate': None, 'name': 'Alfred Cheung'}, 1],
#  [{'id': 156725, 'birthdate': None, 'name': 'Edmond Chevie'}, 1],
#  [{'id': 161205, 'birthdate': None, 'name': 'David Chung'}, 1],
#  [{'id': 161285, 'birthdate': None, 'name': 'Peter Chung'}, 1],
#  [{'id': 163706, 'birthdate': None, 'name': 'Bob Clark'}, 1],
#  [{'id': 163786, 'birthdate': None, 'name': 'Colbert Clark'}, 1],
#  [{'id': 166730, 'birthdate': None, 'name': 'Elmer Clifton'}, 1],
#  [{'id': 166836, 'birthdate': None, 'name': 'Edward F. Cline'}, 1],
#  [{'id': 170306, 'birthdate': None, 'name': 'Stephen Colbert'}, 1],
#  [{'id': 172485, 'birthdate': None, 'name': 'Lewis D. Collins'}, 1],
#  [{'id': 176699, 'birthdate': None, 'name': 'Jack Conway'}, 1],
#  [{'id': 178578, 'birthdate': None, 'name': 'Jodie Copelan'}, 1],
#  [{'id': 178997, 'birthdate': '1966-01-01', 'name': 'Frank Coraci'}, 2],
#  [{'id': 181902, 'birthdate': None, 'name': 'George P. Cosmatos'}, 2],
#  [{'id': 184729, 'birthdate': None, 'name': 'Mark Cowen'}, 1],
#  [{'id': 187981, 'birthdate': None, 'name': 'Donald Crisp'}, 2],
#  [{'id': 188532, 'birthdate': None, 'name': 'Hugh Croise'}, 1],
#  [{'id': 188669, 'birthdate': None, 'name': 'John Cromwell'}, 1],
#  [{'id': 190516, 'birthdate': '1884-01-01', 'name': 'James Cruze'}, 4],
#  [{'id': 194890, 'birthdate': None, 'name': "Mack D'Agostino"}, 1],
#  [{'id': 197636, 'birthdate': None, 'name': 'Stephen Daldry'}, 1],
#  [{'id': 201509, 'birthdate': None, 'name': 'Eric Darnell'}, 1],
#  [{'id': 202088, 'birthdate': None, 'name': 'Jules Dassin'}, 1],
#  [{'id': 203429, 'birthdate': '1939-01-01', 'name': 'Martin Davidson'}, 1],
#  [{'id': 204628, 'birthdate': None, 'name': 'Garth Davis'}, 1],
#  [{'id': 210352, 'birthdate': None, 'name': 'William C. de Mille'}, 1],
#  [{'id': 211823, 'birthdate': None, 'name': 'Steven E. de Souza'}, 1],
#  [{'id': 213100, 'birthdate': None, 'name': 'William Dear'}, 1],
#  [{'id': 213136, 'birthdate': None, 'name': 'Basil Dearden'}, 1],
#  [{'id': 217974, 'birthdate': None, 'name': 'André Delvaux'}, 1],
#  [{'id': 223307, 'birthdate': None, 'name': 'John Dexter'}, 1],
#  [{'id': 225279, 'birthdate': None, 'name': 'Nigel Dick'}, 1],
#  [{'id': 226992, 'birthdate': None, 'name': 'Edward Dillon'}, 1],
#  [{'id': 228262, 'birthdate': None, 'name': 'Mark DiSalle'}, 1],
#  [{'id': 229424, 'birthdate': None, 'name': 'Edward Dmytryk'}, 2],
#  [{'id': 229694, 'birthdate': None, 'name': 'David Dobkin'}, 1],
#  [{'id': 232795, 'birthdate': None, 'name': 'Clive Donner'}, 1],
#  [{'id': 232980, 'birthdate': None, 'name': 'Frank P. Donovan'}, 1],
#  [{'id': 236769, 'birthdate': None, 'name': 'Stan Dragoti'}, 1],
#  [{'id': 245385, 'birthdate': None, 'name': 'Allan Dwan'}, 1],
#  [{'id': 250445, 'birthdate': None, 'name': 'Walter Edwards'}, 14],
#  [{'id': 252135, 'birthdate': None, 'name': 'Breck Eisner'}, 1],
#  [{'id': 256831, 'birthdate': None, 'name': 'Cy Endfield'}, 1],
#  [{'id': 258015, 'birthdate': None, 'name': 'Ray Enright'}, 1],
#  [{'id': 259006, 'birthdate': None, 'name': 'A.F. Erickson'}, 1],
#  [{'id': 267309, 'birthdate': None, 'name': 'James Fargo'}, 2],
#  [{'id': 268513, 'birthdate': None, 'name': 'John Farrow'}, 2],
#  [{'id': 269463, 'birthdate': '1966-01-01', 'name': 'Jon Favreau'}, 2],
#  [{'id': 271344, 'birthdate': None, 'name': 'Seymour Felix'}, 1],
#  [{'id': 275629, 'birthdate': None, 'name': 'Glenn Ficarra'}, 1],
#  [{'id': 281507, 'birthdate': None, 'name': 'Richard Fleischer'}, 2],
#  [{'id': 282708, 'birthdate': None, 'name': 'Isaac Florentine'}, 1],
#  [{'id': 283500, 'birthdate': None, 'name': 'John Flynn'}, 1],
#  [{'id': 286379, 'birthdate': '1893-01-01', 'name': 'Tom Forman'}, 1],
#  [{'id': 286975, 'birthdate': None, 'name': 'Marc Forster'}, 1],
#  [{'id': 289381, 'birthdate': None, 'name': 'Bryan Foy'}, 1],
#  [{'id': 291035, 'birthdate': None, 'name': 'Melvin Frank'}, 1],
#  [{'id': 291201, 'birthdate': None, 'name': 'Cyril Frankel'}, 1],
#  [{'id': 291205, 'birthdate': None, 'name': 'David Frankel'}, 3],
#  [{'id': 291548, 'birthdate': None, 'name': 'Sidney Franklin'}, 2],
#  [{'id': 292134, 'birthdate': '1889-01-01', 'name': 'Harry L. Fraser'}, 2],
#  [{'id': 296532, 'birthdate': '1935-01-01', 'name': 'Lee Frost'}, 1],
#  [{'id': 307819, 'birthdate': '1894-01-01', 'name': 'Tay Garnett'}, 1],
#  [{'id': 308376, 'birthdate': None, 'name': 'Mick Garris'}, 2],
#  [{'id': 309163, 'birthdate': '1875-01-01', 'name': 'Louis J. Gasnier'}, 1],
#  [{'id': 313623, 'birthdate': None, 'name': 'Terry George'}, 2],
#  [{'id': 316794, 'birthdate': None, 'name': 'Charles Giblyn'}, 1],
#  [{'id': 318150, 'birthdate': None, 'name': 'Lewis Gilbert'}, 3],
#  [{'id': 318947, 'birthdate': None, 'name': 'Jim Gillespie'}, 1],
#  [{'id': 320588, 'birthdate': None, 'name': 'Bob Giraldi'}, 1],
#  [{'id': 320637, 'birthdate': None, 'name': 'Bernard Girard'}, 1],
#  [{'id': 322515, 'birthdate': None, 'name': 'John Glen'}, 5],
#  [{'id': 322865, 'birthdate': None, 'name': 'Arne Glimcher'}, 1],
#  [{'id': 324610, 'birthdate': None, 'name': 'Aaron A. Goffman'}, 1],
#  [{'id': 324875, 'birthdate': None, 'name': 'Menahem Golan'}, 1],
#  [{'id': 326040, 'birthdate': None, 'name': 'Akiva Goldsman'}, 1],
#  [{'id': 335455, 'birthdate': None, 'name': 'James Edward Grant'}, 1],
#  [{'id': 336620, 'birthdate': None, 'name': 'F. Gary Gray'}, 2],
#  [{'id': 336695, 'birthdate': None, 'name': 'James Gray'}, 4],
#  [{'id': 337586, 'birthdate': None, 'name': 'Alfred E. Green'}, 1],
#  [{'id': 339030, 'birthdate': None, 'name': 'Paul Greengrass'}, 1],
#  [{'id': 344496, 'birthdate': None, 'name': 'Adrian Grunberg'}, 1],
#  [{'id': 346549, 'birthdate': None, 'name': 'Charles Guggenheim'}, 1],
#  [{'id': 347086, 'birthdate': None, 'name': 'John Guillermin'}, 2],
#  [{'id': 348181, 'birthdate': None, 'name': 'James Gunn'}, 2],
#  [{'id': 351918, 'birthdate': None, 'name': 'Charles F. Haas'}, 1],
#  [{'id': 355032, 'birthdate': None, 'name': 'William Hale'}, 1],
#  [{'id': 357891, 'birthdate': None, 'name': 'Guy Hamilton'}, 5],
#  [{'id': 359189, 'birthdate': None, 'name': 'Sanping Han'}, 2],
#  [{'id': 359387, 'birthdate': None, 'name': 'John Lee Hancock'}, 1],
#  [{'id': 362566, 'birthdate': None, 'name': 'Catherine Hardwicke'}, 1],
#  [{'id': 363553, 'birthdate': None, 'name': 'Robert Harmon'}, 1],
#  [{'id': 368871, 'birthdate': None, 'name': 'Henry Hathaway'}, 7],
#  [{'id': 381273, 'birthdate': None, 'name': 'John Herzfeld'}, 2],
#  [{'id': 382779, 'birthdate': None, 'name': 'Douglas Hickox'}, 1],
#  [{'id': 384276, 'birthdate': None, 'name': 'George W. Hill'}, 1],
#  [{'id': 394399, 'birthdate': None, 'name': 'E. Mason Hopper'}, 6],
#  [{'id': 394409, 'birthdate': None, 'name': 'Jerry Hopper'}, 1],
#  [{'id': 395776, 'birthdate': None, 'name': 'Louis J. Horvitz'}, 1],
#  [{'id': 397227, 'birthdate': None, 'name': 'David Howard'}, 1],
#  [{'id': 400850, 'birthdate': None, 'name': 'Patrick Hughes'}, 1],
#  [{'id': 401176, 'birthdate': None, 'name': 'Ann Hui'}, 1],
#  [{'id': 402597, 'birthdate': None, 'name': 'Peter R. Hunt'}, 1],
#  [{'id': 404606, 'birthdate': None, 'name': 'Brian G. Hutton'}, 2],
#  [{'id': 404882, 'birthdate': None, 'name': 'John Hyams'}, 3],
#  [{'id': 405632, 'birthdate': None, 'name': 'Mikael Håfström'}, 1],
#  [{'id': 410139, 'birthdate': None, 'name': 'John Irvin'}, 1],
#  [{'id': 410864, 'birthdate': None, 'name': 'Wayne Isham'}, 2],
#  [{'id': 411025, 'birthdate': None, 'name': 'Gakuryû Ishii'}, 1],
#  [{'id': 411477, 'birthdate': None, 'name': 'Neal Israel'}, 1],
#  [{'id': 419265, 'birthdate': None, 'name': 'Leigh Jason'}, 1],
#  [{'id': 422484, 'birthdate': '1926-01-01', 'name': 'Norman Jewison'}, 3],
#  [{'id': 429964, 'birthdate': None, 'name': 'Gregor Jordan'}, 1],
#  [{'id': 434571, 'birthdate': None, 'name': 'Jeremy Kagan'}, 1],
#  [{'id': 435563, 'birthdate': None, 'name': 'Mikhail Kalatozov'}, 1],
#  [{'id': 436284, 'birthdate': None, 'name': 'Scott Kalvert'}, 5],
#  [{'id': 437356, 'birthdate': None, 'name': 'Joseph Kane'}, 5],
#  [{'id': 437900, 'birthdate': None, 'name': 'Hal Kanter'}, 1],
#  [{'id': 439597, 'birthdate': None, 'name': 'Phil Karlson'}, 1],
#  [{'id': 440171, 'birthdate': None, 'name': 'Eric Karson'}, 1],
#  [{'id': 440913, 'birthdate': None, 'name': 'Mathieu Kassovitz'}, 1],
#  [{'id': 441914, 'birthdate': None, 'name': 'Lee H. Katzin'}, 1],
#  [{'id': 442241, 'birthdate': None, 'name': 'Philip Kaufman'}, 2],
#  [{'id': 443181, 'birthdate': '1963-01-01', 'name': 'Stephen Kay'}, 1],
#  [{'id': 446129, 'birthdate': None, 'name': 'Ray Kellogg'}, 1],
#  [{'id': 446837, 'birthdate': None, 'name': 'Rory Kelly'}, 1],
#  [{'id': 447944, 'birthdate': None, 'name': 'Burt Kennedy'}, 2],
#  [{'id': 448915, 'birthdate': None, 'name': 'Erle C. Kenton'}, 3],
#  [{'id': 449984, 'birthdate': None, 'name': 'Irvin Kershner'}, 4],
#  [{'id': 453115, 'birthdate': '1982-01-01', 'name': 'Taran Killam'}, 1],
#  [{'id': 453518, 'birthdate': None, 'name': 'Jee-woon Kim'}, 2],
#  [{'id': 464846, 'birthdate': None, 'name': 'Andrey Konchalovskiy'}, 1],
#  [{'id': 466113, 'birthdate': None, 'name': 'Zoltan Korda'}, 1],
#  [{'id': 467646, 'birthdate': None, 'name': 'Ted Kotcheff'}, 1],
#  [{'id': 469694, 'birthdate': None, 'name': 'Wayne Kramer'}, 1],
#  [{'id': 470443, 'birthdate': '1953-01-01', 'name': 'Gérard Krawczyk'}, 1],
#  [{'id': 474539, 'birthdate': None, 'name': 'Buzz Kulik'}, 1],
#  [{'id': 477035, 'birthdate': None, 'name': 'Corey Yuen'}, 1],
#  [{'id': 482681, 'birthdate': None, 'name': 'Ringo Lam'}, 4],
#  [{'id': 485647, 'birthdate': None, 'name': 'Sidney Lanfield'}, 2],
#  [{'id': 486524, 'birthdate': None, 'name': 'John Langley'}, 1],
#  [{'id': 494885, 'birthdate': None, 'name': 'Philip Leacock'}, 1],
#  [{'id': 496505, 'birthdate': None, 'name': 'D. Ross Lederman'}, 3],
#  [{'id': 498064, 'birthdate': None, 'name': 'Raymond Lee'}, 1],
#  [{'id': 501539, 'birthdate': None, 'name': 'John Lemont'}, 1],
#  [{'id': 502987, 'birthdate': None, 'name': 'Po-Chih Leong'}, 1],
#  [{'id': 503777, 'birthdate': '1900-01-01', 'name': 'Mervyn LeRoy'}, 1],
#  [{'id': 504495, 'birthdate': None, 'name': 'Mark L. Lester'}, 1],
#  [{'id': 504513, 'birthdate': None, 'name': 'Richard Lester'}, 2],
#  [{'id': 504802, 'birthdate': None, 'name': 'Sheldon Lettich'}, 4],
#  [{'id': 504980, 'birthdate': None, 'name': 'Patrick Leung'}, 1],
#  [{'id': 505152, 'birthdate': None, 'name': 'Brian Levant'}, 2],
#  [{'id': 505415, 'birthdate': None, 'name': 'William A. Levey'}, 1],
#  [{'id': 510912, 'birthdate': None, 'name': 'Justin Lin'}, 4],
#  [{'id': 514908, 'birthdate': None, 'name': 'Ching-Chieh Lin'}, 1],
#  [{'id': 515891, 'birthdate': None, 'name': 'Luis Llosa'}, 1],
#  [{'id': 517597, 'birthdate': None, 'name': 'Joshua Logan'}, 1],
#  [{'id': 517768, 'birthdate': None, 'name': 'Dimitri Logothetis'}, 1],
#  [{'id': 518644, 'birthdate': None, 'name': 'Richard Loncraine'}, 1],
#  [{'id': 520749, 'birthdate': None, 'name': 'Robert Lorenz'}, 1],
#  [{'id': 522503, 'birthdate': None, 'name': 'Laura Lovelace'}, 1],
#  [{'id': 523893, 'birthdate': '1898-01-01', 'name': 'Arthur Lubin'}, 8],
#  [{'id': 524995, 'birthdate': None, 'name': 'Edward Ludwig'}, 3],
#  [{'id': 525659, 'birthdate': None, 'name': 'Robert Luketic'}, 1],
#  [{'id': 525782, 'birthdate': None, 'name': 'Peter Malota'}, 1],
#  [{'id': 527350, 'birthdate': None, 'name': 'William Lustig'}, 2],
#  [{'id': 533691, 'birthdate': None, 'name': 'Angus MacLane'}, 1],
#  [{'id': 536087, 'birthdate': None, 'name': 'Scott Magill'}, 1],
#  [{'id': 538353, 'birthdate': None, 'name': 'Karl Maka'}, 2],
#  [{'id': 539950, 'birthdate': None, 'name': 'David Mallet'}, 1],
#  [{'id': 540330, 'birthdate': None, 'name': 'Bruce Malmuth'}, 1],
#  [{'id': 542539, 'birthdate': None, 'name': 'Tom Mankiewicz'}, 1],
#  [{'id': 547446, 'birthdate': None, 'name': 'Edwin L. Marin'}, 1],
#  [{'id': 549658, 'birthdate': '1937-01-01', 'name': 'Richard Marquand'}, 2],
#  [{'id': 549820, 'birthdate': None, 'name': 'Gregory Marquette'}, 1],
#  [{'id': 553662, 'birthdate': None, 'name': 'Philippe Martinez'}, 1],
#  [{'id': 556826, 'birthdate': '1961-10-07', 'name': 'James Riffel'}, 7],
#  [{'id': 557857, 'birthdate': None, 'name': 'Armand Mastroianni'}, 1],
#  [{'id': 562845, 'birthdate': None, 'name': 'Archie Mayo'}, 2],
#  [{'id': 568915, 'birthdate': None, 'name': 'William C. McGann'}, 1],
#  [{'id': 569645, 'birthdate': '1880-01-01', 'name': 'J.P. McGowan'}, 1],
#  [{'id': 570912, 'birthdate': None, 'name': 'Adam McKay'}, 1],
#  [{'id': 572132, 'birthdate': None, 'name': 'Andrew V. McLaglen'}, 5],
#  [{'id': 576509, 'birthdate': None, 'name': 'Alan Mehrez'}, 1],
#  [{'id': 577654, 'birthdate': '1877-01-01', 'name': 'George Melford'}, 5],
#  [{'id': 578446, 'birthdate': None, 'name': 'Rob Meltzer'}, 1],
#  [{'id': 581772, 'birthdate': None, 'name': 'William Mesa'}, 1],
#  [{'id': 583292, 'birthdate': None, 'name': 'Nicholas Meyer'}, 1],
#  [{'id': 585011, 'birthdate': None, 'name': 'Roger Michell'}, 1],
#  [{'id': 586281, 'birthdate': None, 'name': 'Takashi Miike'}, 1],
#  [{'id': 587518, 'birthdate': '1944-01-01', 'name': 'John Milius'}, 2],
#  [{'id': 587706, 'birthdate': None, 'name': 'Stuart Millar'}, 1],
#  [{'id': 588183, 'birthdate': None, 'name': 'David Miller'}, 1],
#  [{'id': 588340, 'birthdate': '1957-01-01', 'name': 'Frank Miller'}, 1],
#  [{'id': 592824, 'birthdate': None, 'name': 'Bob Misiorowski'}, 1],
#  [{'id': 594624, 'birthdate': None, 'name': 'Moshé Mizrahi'}, 1],
#  [{'id': 598671, 'birthdate': None, 'name': 'Shaun Monson'}, 1],
#  [{'id': 609236, 'birthdate': None, 'name': 'Jonathan Mostow'}, 1],
#  [{'id': 609549, 'birthdate': None, 'name': 'Greg Mottola'}, 1],
#  [{'id': 610831, 'birthdate': None, 'name': 'Gabriele Muccino'}, 2],
#  [{'id': 611683, 'birthdate': '1953-01-01', 'name': 'Russell Mulcahy'}, 2],
#  [{'id': 612322, 'birthdate': None, 'name': 'Robert Mulligan'}, 2],
#  [{'id': 615868, 'birthdate': None, 'name': 'Bernard Vorhaus'}, 2],
#  [{'id': 623768, 'birthdate': '1911-01-01', 'name': 'Ronald Neame'}, 1],
#  [{'id': 624102, 'birthdate': '1931-01-01', 'name': 'Hal Needham'}, 1],
#  [{'id': 624714, 'birthdate': None, 'name': 'Marshall Neilan'}, 1],
#  [{'id': 624756, 'birthdate': None, 'name': 'Roy William Neill'}, 1],
#  [{'id': 625680, 'birthdate': None, 'name': 'Ralph Nelson'}, 1],
#  [{'id': 634240, 'birthdate': '1970-07-30', 'name': 'Christopher Nolan'}, 13],
#  [{'id': 635759, 'birthdate': None, 'name': 'Stephen Norrington'}, 1],
#  [{'id': 636165, 'birthdate': None, 'name': 'Bill Norton'}, 1],
#  [{'id': 637518, 'birthdate': None, 'name': 'Phillip Noyce'}, 2],
#  [{'id': 640466, 'birthdate': None, 'name': "Pat O'Connor"}, 1],
#  [{'id': 646058, 'birthdate': None, 'name': 'Sidney Olcott'}, 1],
#  [{'id': 657499, 'birthdate': None, 'name': 'Bonnie Palef'}, 1],
#  [{'id': 662032, 'birthdate': None, 'name': 'Albert Parker'}, 1],
#  [{'id': 665951, 'birthdate': None, 'name': 'Pasha Patriki'}, 1],
#  [{'id': 668972, 'birthdate': None, 'name': 'Leslie Pearce'}, 1],
#  [{'id': 671501, 'birthdate': None, 'name': 'Scott Pembroke'}, 1],
#  [{'id': 675094, 'birthdate': None, 'name': 'Hart Perry'}, 1],
#  [{'id': 678928, 'birthdate': None, 'name': 'Joseph Pevney'}, 1],
#  [{'id': 680846, 'birthdate': None, 'name': 'Todd Phillips'}, 1],
#  [{'id': 682744, 'birthdate': None, 'name': 'Carl Pierson'}, 2],
#  [{'id': 687964, 'birthdate': None, 'name': 'Jeremy Podeswa'}, 1],
#  [{'id': 691074, 'birthdate': None, 'name': 'Amanda Pope'}, 1],
#  [{'id': 692872, 'birthdate': None, 'name': 'Ted Post'}, 2],
#  [{'id': 694090, 'birthdate': '1904-01-01', 'name': 'Dick Powell'}, 1],
#  [{'id': 695779, 'birthdate': None, 'name': 'Michael Preece'}, 1],
#  [{'id': 695928, 'birthdate': None, 'name': 'Bill Premin'}, 1],
#  [{'id': 695937, 'birthdate': None, 'name': 'Otto Preminger'}, 1],
#  [{'id': 706182, 'birthdate': '1933-01-01', 'name': 'Bob Rafelson'}, 1],
#  [{'id': 708903, 'birthdate': None, 'name': 'Lynne Ramsay'}, 1],
#  [{'id': 712947, 'birthdate': None, 'name': 'Nicholas Ray'}, 1],
#  [{'id': 718645, 'birthdate': None, 'name': 'Ivan Reitman'}, 5],
#  [{'id': 719208, 'birthdate': None, 'name': 'Chris Renaud'}, 1],
#  [{'id': 721817, 'birthdate': None, 'name': 'Kevin Reynolds'}, 1],
#  [{'id': 724059, 'birthdate': None, 'name': 'Dick Richards'}, 1],
#  [{'id': 728688, 'birthdate': None, 'name': 'Martin Ritt'}, 1],
#  [{'id': 731596, 'birthdate': None, 'name': 'Stephen Roberts'}, 2],
#  [{'id': 731910, 'birthdate': None, 'name': 'John S. Robertson'}, 1],
#  [{'id': 733692, 'birthdate': None, 'name': 'Marc Rocco'}, 1],
#  [{'id': 734319, 'birthdate': None, 'name': 'Alexandre Rockwell'}, 1],
#  [{'id': 734747, 'birthdate': None, 'name': 'Mic Rodgers'}, 1],
#  [{'id': 736610, 'birthdate': None, 'name': 'Albert S. Rogell'}, 1],
#  [{'id': 742819, 'birthdate': None, 'name': 'Rick Rosenthal'}, 1],
#  [{'id': 747849, 'birthdate': None, 'name': 'Joseph Ruben'}, 1],
#  [{'id': 750701, 'birthdate': None, 'name': 'Richard Rush'}, 1],
#  [{'id': 751080, 'birthdate': None, 'name': 'Chuck Russell'}, 1],
#  [{'id': 751221, 'birthdate': None, 'name': 'Jay Russell'}, 1],
#  [{'id': 751577, 'birthdate': None, 'name': 'Anthony Russo'}, 2],
#  [{'id': 753423, 'birthdate': None, 'name': 'Seung-wan Ryoo'}, 1],
#  [{'id': 758541, 'birthdate': None, 'name': 'David Salle'}, 1],
#  [{'id': 761498, 'birthdate': None, 'name': 'Chris Sanders'}, 1],
#  [{'id': 763453, 'birthdate': None, 'name': 'Alfred Santell'}, 1],
#  [{'id': 764776, 'birthdate': None, 'name': 'Deran Sarafian'}, 1],
#  [{'id': 764781, 'birthdate': '1930-01-01', 'name': 'Richard C. Sarafian'}, 1],
#  [{'id': 767303, 'birthdate': None, 'name': 'Henry W. Savage'}, 1],
#  [{'id': 769585, 'birthdate': None, 'name': 'Armand Schaefer'}, 1],
#  [{'id': 769615, 'birthdate': None, 'name': 'George Schaefer'}, 1],
#  [{'id': 769874, 'birthdate': None, 'name': 'Franklin J. Schaffner'}, 1],
#  [{'id': 770961, 'birthdate': None, 'name': 'Fred Schepisi'}, 2],
#  [{'id': 773689, 'birthdate': None, 'name': 'Aaron Schneider'}, 1],
#  [{'id': 774214, 'birthdate': None, 'name': 'Robert Allen Schnitzer'}, 1],
#  [{'id': 776317, 'birthdate': None, 'name': 'Michael Schultz'}, 1],
#  [{'id': 776650, 'birthdate': None, 'name': 'Michelle Schumacher'}, 1],
#  [{'id': 778735, 'birthdate': None, 'name': 'Cathy Scorsese'}, 1],
#  [{'id': 779386, 'birthdate': None, 'name': 'Jordan Scott'}, 1],
#  [{'id': 781292, 'birthdate': None, 'name': 'Edward Sedgwick'}, 1],
#  [{'id': 781842, 'birthdate': None, 'name': 'Peter Segal'}, 1],
#  [{'id': 782381, 'birthdate': None, 'name': 'Arthur Allan Seidelman'}, 1],
#  [{'id': 782597, 'birthdate': None, 'name': 'Lewis Seiler'}, 2],
#  [{'id': 782682, 'birthdate': None, 'name': 'William A. Seiter'}, 3],
#  [{'id': 782707, 'birthdate': None, 'name': 'George B. Seitz'}, 1],
#  [{'id': 783544, 'birthdate': None, 'name': 'David Seltzer'}, 1],
#  [{'id': 788202, 'birthdate': None, 'name': 'Adam Shankman'}, 1],
#  [{'id': 788234, 'birthdate': None, 'name': 'John Patrick Shanley'}, 1],
#  [{'id': 789520, 'birthdate': None, 'name': 'Melville Shavelson'}, 1],
#  [{'id': 789748, 'birthdate': None, 'name': 'Harold M. Shaw'}, 1],
#  [{'id': 790715, 'birthdate': '1945-01-01', 'name': 'Penelope Spheeris'}, 1],
#  [{'id': 792450, 'birthdate': None, 'name': 'George Sherman'}, 9],
#  [{'id': 796117, 'birthdate': None, 'name': 'M. Night Shyamalan'}, 3],
#  [{'id': 796657, 'birthdate': None, 'name': 'Scott Sidney'}, 1],
#  [{'id': 796923, 'birthdate': '1912-01-01', 'name': 'Don Siegel'}, 7],
#  [{'id': 797854, 'birthdate': None, 'name': 'Joel Silberg'}, 1],
#  [{'id': 797869, 'birthdate': None, 'name': 'Brad Silberling'}, 1],
#  [{'id': 798899, 'birthdate': None, 'name': 'David Silverman'}, 1],
#  [{'id': 814716, 'birthdate': None, 'name': 'Ömer Faruk Sorak'}, 1],
#  [{'id': 818547, 'birthdate': None, 'name': 'Scott Spiegel'}, 2],
#  [{'id': 828419, 'birthdate': None, 'name': 'George Stevens'}, 1],
#  [{'id': 828720, 'birthdate': None, 'name': 'Robert Stevens'}, 1],
#  [{'id': 829038, 'birthdate': None, 'name': 'Robert Stevenson'}, 1],
#  [{'id': 831577, 'birthdate': None, 'name': 'Benjamin Stoloff'}, 1],
#  [{'id': 833965, 'birthdate': None, 'name': 'Frank R. Strayer'}, 3],
#  [{'id': 836316, 'birthdate': None, 'name': 'Rollin S. Sturgeon'}, 2],
#  [{'id': 836328, 'birthdate': None, 'name': 'John Sturges'}, 5],
#  [{'id': 842140, 'birthdate': '1959-01-01', 'name': 'Julia Sweeney'}, 1],
#  [{'id': 848414, 'birthdate': None, 'name': 'Lee Tamahori'}, 1],
#  [{'id': 851537, 'birthdate': None, 'name': 'Norman Taurog'}, 2],
#  [{'id': 851724, 'birthdate': None, 'name': 'Bertrand Tavernier'}, 1],
#  [{'id': 851930, 'birthdate': None, 'name': 'Alan Taylor'}, 1],
#  [{'id': 855035, 'birthdate': None, 'name': 'Andy Tennant'}, 1],
#  [{'id': 855912, 'birthdate': None, 'name': 'Tom Terriss'}, 1],
#  [{'id': 858873, 'birthdate': None, 'name': 'Gerald Thomas'}, 1],
#  [{'id': 861336, 'birthdate': None, 'name': 'Robert Thornby'}, 1],
#  [{'id': 861703, 'birthdate': None, 'name': 'Richard Thorpe'}, 1],
#  [{'id': 862312, 'birthdate': None, 'name': 'Denis Thybaud'}, 1],
#  [{'id': 864006, 'birthdate': None, 'name': 'James Tinling'}, 1],
#  [{'id': 871860, 'birthdate': None, 'name': 'Jeff Tremaine'}, 1],
#  [{'id': 876227, 'birthdate': None, 'name': 'Richard Tuggle'}, 1],
#  [{'id': 876440, 'birthdate': None, 'name': 'Montgomery Tully'}, 1],
#  [{'id': 878338, 'birthdate': None, 'name': 'Frank Tuttle'}, 1],
#  [{'id': 878638, 'birthdate': None, 'name': 'David Twohy'}, 3],
#  [{'id': 878756, 'birthdate': None, 'name': 'Tom Tykwer'}, 2],
#  [{'id': 881279, 'birthdate': None, 'name': 'Lee Unkrich'}, 1],
#  [{'id': 887174, 'birthdate': '1929-01-01', 'name': 'Buddy Van Horn'}, 3],
#  [{'id': 891114, 'birthdate': None, 'name': 'Tom Vaughan'}, 1],
#  [{'id': 893207, 'birthdate': None, 'name': 'Louis Venosta'}, 1],
#  [{'id': 896542, 'birthdate': None, 'name': 'King Vidor'}, 2],
#  [{'id': 897085, 'birthdate': None, 'name': 'Robert G. Vignola'}, 3],
#  [{'id': 898288, 'birthdate': None, 'name': 'Denis Villeneuve'}, 1],
#  [{'id': 899121, 'birthdate': None, 'name': 'Thomas Vinterberg'}, 1],
#  [{'id': 903049, 'birthdate': None, 'name': 'Josef von Sternberg'}, 1],
#  [{'id': 905729, 'birthdate': None, 'name': 'George Waggner'}, 2],
#  [{'id': 908831, 'birthdate': None, 'name': 'Richard Wallace'}, 1],
#  [{'id': 909759, 'birthdate': None, 'name': 'Mark A. Walsh'}, 1],
#  [{'id': 909825, 'birthdate': None, 'name': 'Raoul Walsh'}, 2],
#  [{'id': 911926, 'birthdate': None, 'name': 'William Wiard'}, 1],
#  [{'id': 916224, 'birthdate': None, 'name': 'Millard Webb'}, 1],
#  [{'id': 916665, 'birthdate': None, 'name': 'Lois Weber'}, 1],
#  [{'id': 917358, 'birthdate': None, 'name': 'Stephen Weeks'}, 1],
#  [{'id': 920074, 'birthdate': '1896-01-01', 'name': 'William A. Wellman'}, 6],
#  [{'id': 922346, 'birthdate': None, 'name': 'Simon West'}, 1],
#  [{'id': 926171, 'birthdate': None, 'name': 'Phil Whitman'}, 1],
#  [{'id': 928214, 'birthdate': None, 'name': 'Herbert Wilcox'}, 1],
#  [{'id': 929649, 'birthdate': None, 'name': 'Irvin Willat'}, 1],
#  [{'id': 934863, 'birthdate': None, 'name': 'Harry Winer'}, 1],
#  [{'id': 936404, 'birthdate': None, 'name': 'Robert Wise'}, 2],
#  [{'id': 936482, 'birthdate': None, 'name': 'Len Wiseman'}, 1],
#  [{'id': 936767, 'birthdate': None, 'name': 'Chester Withey'}, 1],
#  [{'id': 939992, 'birthdate': None, 'name': 'Sam Wood'}, 2],
#  [{'id': 942048, 'birthdate': None, 'name': 'John Griffith Wray'}, 1],
#  [{'id': 942081, 'birthdate': None, 'name': 'Casper Wrede'}, 1],
#  [{'id': 942367, 'birthdate': None, 'name': 'Edgar Wright'}, 1],
#  [{'id': 942611, 'birthdate': '1894-01-01', 'name': 'Mack V. Wright'}, 4],
#  [{'id': 942862, 'birthdate': None, 'name': 'Tenny Wright'}, 2],
#  [{'id': 946811, 'birthdate': None, 'name': 'Peter Yates'}, 1],
#  [{'id': 947105, 'birthdate': None, 'name': 'Irvin S. Yeaworth Jr.'}, 1],
#  [{'id': 950109, 'birthdate': '1915-01-01', 'name': 'Terence Young'}, 4],
#  [{'id': 950226, 'birthdate': None, 'name': 'Ben Younger'}, 1],
#  [{'id': 950775, 'birthdate': None, 'name': 'Jennifer Yuh Nelson'}, 1],
#  [{'id': 950819, 'birthdate': None, 'name': 'James Yukich'}, 2],
#  [{'id': 951731, 'birthdate': None, 'name': 'Peter Zadek'}, 1],
#  [{'id': 957263, 'birthdate': None, 'name': 'Joseph Zito'}, 1],
#  [{'id': 958387, 'birthdate': '1950-01-01', 'name': 'Jerry Zucker'}, 1],
#  [{'id': 959034, 'birthdate': None, 'name': 'Joel Zwick'}, 1],
#  [{'id': 973425, 'birthdate': None, 'name': 'Annie Leibovitz'}, 1],
#  [{'id': 989998, 'birthdate': None, 'name': 'Chao-Bin Su'}, 1],
#  [{'id': 1021166, 'birthdate': None, 'name': 'Bonner Bellew'}, 1],
#  [{'id': 1071883, 'birthdate': None, 'name': 'Jeffrey Abelson'}, 1],
#  [{'id': 1079587, 'birthdate': None, 'name': 'Thierry Coup'}, 1],
#  [{'id': 1083489, 'birthdate': None, 'name': 'Kevin Munroe'}, 1],
#  [{'id': 1125560, 'birthdate': None, 'name': 'Neil Cicierega'}, 2],
#  [{'id': 1159647, 'birthdate': None, 'name': 'Punit Malhotra'}, 1],
#  [{'id': 1191002, 'birthdate': None, 'name': 'Kei Sek'}, 1],
#  [{'id': 1193701, 'birthdate': None, 'name': 'Tristan Aurouet'}, 1],
#  [{'id': 1195760, 'birthdate': None, 'name': 'Damian Nieman'}, 1],
#  [{'id': 1200693, 'birthdate': None, 'name': 'Gillian Greene'}, 1],
#  [{'id': 1242054, 'birthdate': None, 'name': 'James Ponsoldt'}, 1],
#  [{'id': 1287649, 'birthdate': None, 'name': 'Sabir Khan'}, 1],
#  [{'id': 1333798, 'birthdate': None, 'name': 'Mabrouk El Mechri'}, 1],
#  [{'id': 1349376, 'birthdate': None, 'name': 'Francis Lawrence'}, 2],
#  [{'id': 1350518, 'birthdate': None, 'name': 'Desmond Gumbs'}, 1],
#  [{'id': 1415540, 'birthdate': None, 'name': 'Simon Fellows'}, 2],
#  [{'id': 1481618, 'birthdate': None, 'name': 'Peter Landesman'}, 1],
#  [{'id': 1490123, 'birthdate': None, 'name': 'James Wan'}, 1],
#  [{'id': 1496035, 'birthdate': None, 'name': 'Marc Klasfeld'}, 1],
#  [{'id': 1531337, 'birthdate': None, 'name': 'Shu Mei Chin'}, 1],
#  [{'id': 1580671, 'birthdate': None, 'name': 'Jon S. Baird'}, 1],
#  [{'id': 1589693, 'birthdate': None, 'name': 'Michael A. Seligman'}, 1],
#  [{'id': 1601882, 'birthdate': None, 'name': 'Phil Johnston'}, 1],
#  [{'id': 1702145, 'birthdate': None, 'name': 'Dave Wilson'}, 1],
#  [{'id': 1714255, 'birthdate': None, 'name': 'Elliott Lester'}, 1],
#  [{'id': 1716636, 'birthdate': None, 'name': 'Marielle Heller'}, 1],
#  [{'id': 1747821, 'birthdate': None, 'name': 'Willie McMillon'}, 1],
#  [{'id': 1767218, 'birthdate': None, 'name': 'Lee Toland Krieger'}, 1],
#  [{'id': 1783265, 'birthdate': None, 'name': 'Tim Miller'}, 1],
#  [{'id': 1844237, 'birthdate': None, 'name': 'Chris Miller'}, 1],
#  [{'id': 1868917, 'birthdate': None, 'name': 'Alessandro Carloni'}, 1],
#  [{'id': 1897071, 'birthdate': None, 'name': 'Oleg Stepchenko'}, 1],
#  [{'id': 1921345, 'birthdate': None, 'name': 'Steven C. Miller'}, 1],
#  [{'id': 1942069, 'birthdate': None, 'name': 'Lior Geller'}, 1],
#  [{'id': 1986229, 'birthdate': None, 'name': 'Jim Swaffield'}, 1],
#  [{'id': 2155757, 'birthdate': None, 'name': 'Josh Cooley'}, 1],
#  [{'id': 2182866, 'birthdate': None, 'name': 'Julien Leclercq'}, 1],
#  [{'id': 2357819, 'birthdate': None, 'name': 'Brian A. Miller'}, 1],
#  [{'id': 2372334, 'birthdate': None, 'name': 'Sascha Hartmann'}, 1],
#  [{'id': 2403079, 'birthdate': None, 'name': 'Dominic Burns'}, 1],
#  [{'id': 2588606, 'birthdate': '1969-10-09', 'name': 'Steve McQueen'}, 31],
#  [{'id': 2719270, 'birthdate': None, 'name': 'Kent Jones'}, 2],
#  [{'id': 2871592, 'birthdate': None, 'name': 'Peter Glanz'}, 1],
#  [{'id': 2910380, 'birthdate': None, 'name': 'Howard Guard'}, 1],
#  [{'id': 2939767, 'birthdate': None, 'name': 'Nick Bruno'}, 1],
#  [{'id': 2978815, 'birthdate': None, 'name': 'Keith Parmer'}, 1],
#  [{'id': 3209293, 'birthdate': None, 'name': 'Kyoung-mi Lee'}, 1],
#  [{'id': 3363032, 'birthdate': None, 'name': 'Ryan Coogler'}, 1],
#  [{'id': 3646263, 'birthdate': None, 'name': 'David Briggs'}, 1],
#  [{'id': 3918746, 'birthdate': None, 'name': 'Henry Hobson'}, 1],
#  [{'id': 3934959, 'birthdate': None, 'name': 'Chengpeng Dong'}, 1],
#  [{'id': 4023702, 'birthdate': None, 'name': 'Steven Caple Jr.'}, 1],
#  [{'id': 4414127, 'birthdate': None, 'name': 'Brian MacLochlainn'}, 1],
#  [{'id': 4498875, 'birthdate': None, 'name': 'Andy Maxwell'}, 1],
#  [{'id': 4687062, 'birthdate': None, 'name': 'Zachary K. Eubank'}, 1],
#  [{'id': 4816401, 'birthdate': None, 'name': 'Adil El Arbi'}, 1],
#  [{'id': 5170520, 'birthdate': None, 'name': 'Charles Paek'}, 1],
#  [{'id': 5638280, 'birthdate': None, 'name': 'Morton M. Lewis'}, 1],
#  [{'id': 8477405, 'birthdate': None, 'name': 'Clara Balzary'}, 1],
#  [{'id': 9497376, 'birthdate': None, 'name': 'Pascal Baillien'}, 1],
#  [{'id': 9565029, 'birthdate': None, 'name': 'Jean-Marie Boursicot'}, 1]]

# %%
# applatir en liste de tuples
data_flatten = [ (director_dict['id'], director_dict['name'], director_dict['birthdate'], movie_count )  
         for director_dict, movie_count in data_json ]
data_flatten
# Out:
# [(33, 'Alfred Hitchcock', '1899-08-13', 60),
#  (217, 'Martin Scorsese', '1942-11-17', 48),
#  (229, 'Steven Spielberg', '1946-12-18', 41),
#  (142, 'Clint Eastwood', '1930-05-31', 39),
#  (361, 'Brian De Palma', '1940-09-11', 38),
#  (631, 'Ridley Scott', '1937-11-30', 35),
#  (247, 'John Woo', '1946-09-22', 34),
#  (2588606, 'Steve McQueen', '1969-10-09', 31),
#  (600, 'Sam Raimi', '1959-10-23', 31),
#  (406, 'John Ford', None, 20),
#  (1392, 'Peter Jackson', '1961-10-31', 19),
#  (965, 'Danny Boyle', '1956-10-20', 18),
#  (233, 'Quentin Tarantino', '1963-03-27', 14),
#  (116, 'James Cameron', '1954-08-16', 14),
#  (250445, 'Walter Edwards', None, 14),
#  (102908, 'Robert N. Bradbury', None, 13),
#  (634240, 'Christopher Nolan', '1970-07-30', 13),
#  (94435, 'Bong Joon Ho', '1969-09-14', 12),
#  (1053, 'Ethan Coen', '1957-09-21', 12),
#  (1054, 'Joel Coen', '1954-11-29', 11)]

# %%
# applatir en list de dicts
data_flatten = [ {**director_dict, 'movie_count': movie_count }  
         for director_dict, movie_count in data_json ]
data_flatten
# Out:
# [{'id': 33,
#   'name': 'Alfred Hitchcock',
#   'birthdate': '1899-08-13',
#   'movie_count': 60},
#  {'id': 217,
#   'name': 'Martin Scorsese',
#   'birthdate': '1942-11-17',
#   'movie_count': 48},
#  {'id': 229,
#   'name': 'Steven Spielberg',
#   'birthdate': '1946-12-18',
#   'movie_count': 41},
#  {'id': 142,
#   'name': 'Clint Eastwood',
#   'birthdate': '1930-05-31',
#   'movie_count': 39},
#  {'id': 361,
#   'name': 'Brian De Palma',
#   'birthdate': '1940-09-11',
#   'movie_count': 38},
#  {'id': 631,
#   'name': 'Ridley Scott',
#   'birthdate': '1937-11-30',
#   'movie_count': 35},
#  {'id': 247, 'name': 'John Woo', 'birthdate': '1946-09-22', 'movie_count': 34},
#  {'id': 2588606,
#   'name': 'Steve McQueen',
#   'birthdate': '1969-10-09',
#   'movie_count': 31},
#  {'id': 600,
#   'name': 'Sam Raimi',
#   'birthdate': '1959-10-23',
#   'movie_count': 31},
#  {'id': 406, 'name': 'John Ford', 'birthdate': None, 'movie_count': 20},
#  {'id': 1392,
#   'name': 'Peter Jackson',
#   'birthdate': '1961-10-31',
#   'movie_count': 19},
#  {'id': 965,
#   'name': 'Danny Boyle',
#   'birthdate': '1956-10-20',
#   'movie_count': 18},
#  {'id': 233,
#   'name': 'Quentin Tarantino',
#   'birthdate': '1963-03-27',
#   'movie_count': 14},
#  {'id': 116,
#   'name': 'James Cameron',
#   'birthdate': '1954-08-16',
#   'movie_count': 14},
#  {'id': 250445,
#   'name': 'Walter Edwards',
#   'birthdate': None,
#   'movie_count': 14},
#  {'id': 102908,
#   'name': 'Robert N. Bradbury',
#   'birthdate': None,
#   'movie_count': 13},
#  {'id': 634240,
#   'name': 'Christopher Nolan',
#   'birthdate': '1970-07-30',
#   'movie_count': 13},
#  {'id': 94435,
#   'name': 'Bong Joon Ho',
#   'birthdate': '1969-09-14',
#   'movie_count': 12},
#  {'id': 1053,
#   'name': 'Ethan Coen',
#   'birthdate': '1957-09-21',
#   'movie_count': 12},
#  {'id': 1054,
#   'name': 'Joel Coen',
#   'birthdate': '1954-11-29',
#   'movie_count': 11}]

# %%
dfStatsMovieByDirector = pd.DataFrame(data_flatten)
dfStatsMovieByDirector.set_index('id', inplace=True)
dfStatsMovieByDirector
# Out:
#                        name   birthdate  movie_count
# id
# 33         Alfred Hitchcock  1899-08-13           60
# 217         Martin Scorsese  1942-11-17           48
# 229        Steven Spielberg  1946-12-18           41
# 142          Clint Eastwood  1930-05-31           39
# 361          Brian De Palma  1940-09-11           38
# 631            Ridley Scott  1937-11-30           35
# 247                John Woo  1946-09-22           34
# 2588606       Steve McQueen  1969-10-09           31
# 600               Sam Raimi  1959-10-23           31
# 406               John Ford        None           20
# 1392          Peter Jackson  1961-10-31           19
# 965             Danny Boyle  1956-10-20           18
# 233       Quentin Tarantino  1963-03-27           14
# 116           James Cameron  1954-08-16           14
# 250445       Walter Edwards        None           14
# 102908   Robert N. Bradbury        None           13
# 634240    Christopher Nolan  1970-07-30           13
# 94435          Bong Joon Ho  1969-09-14           12
# 1053             Ethan Coen  1957-09-21           12
# 1054              Joel Coen  1954-11-29           11

# %%
dfStatsMovieByDirector.loc[33].birthdate
# Out:
# '1899-08-13'

# %%
datetime.strptime('1899-08-13', '%Y-%m-%d').date()
# Out:
# datetime.date(1899, 8, 13)

# %%
date.fromisoformat('1899-08-13')
# Out:
# datetime.date(1899, 8, 13)

# %%
dfStatsMovieByDirector[dfStatsMovieByDirector.birthdate.isnull()]
# Out:
#                       name birthdate  movie_count
# id
# 406              John Ford      None           20
# 250445      Walter Edwards      None           14
# 102908  Robert N. Bradbury      None           13

# %%
dfStatsMovieByDirector[~dfStatsMovieByDirector.birthdate.isnull()].birthdate.apply(date.fromisoformat)
# Out:
# id
# 33         1899-08-13
# 217        1942-11-17
# 229        1946-12-18
# 142        1930-05-31
# 361        1940-09-11
# 631        1937-11-30
# 247        1946-09-22
# 2588606    1969-10-09
# 600        1959-10-23
# 1392       1961-10-31
# 965        1956-10-20
# 233        1963-03-27
# 116        1954-08-16
# 634240     1970-07-30
# 94435      1969-09-14
# 1053       1957-09-21
# 1054       1954-11-29
# Name: birthdate, dtype: object

# %%
# def fromisoformat_or_none(dt):
#    return date.fromisoformat(bd) if bd is not None else None

dfStatsMovieByDirector.birthdate = dfStatsMovieByDirector.birthdate.apply(
    lambda bd: date.fromisoformat(bd) if bd is not None else None)
dfStatsMovieByDirector
# Out:
#                        name   birthdate  movie_count
# id
# 33         Alfred Hitchcock  1899-08-13           60
# 217         Martin Scorsese  1942-11-17           48
# 229        Steven Spielberg  1946-12-18           41
# 142          Clint Eastwood  1930-05-31           39
# 361          Brian De Palma  1940-09-11           38
# 631            Ridley Scott  1937-11-30           35
# 247                John Woo  1946-09-22           34
# 2588606       Steve McQueen  1969-10-09           31
# 600               Sam Raimi  1959-10-23           31
# 406               John Ford        None           20
# 1392          Peter Jackson  1961-10-31           19
# 965             Danny Boyle  1956-10-20           18
# 233       Quentin Tarantino  1963-03-27           14
# 116           James Cameron  1954-08-16           14
# 250445       Walter Edwards        None           14
# 102908   Robert N. Bradbury        None           13
# 634240    Christopher Nolan  1970-07-30           13
# 94435          Bong Joon Ho  1969-09-14           12
# 1053             Ethan Coen  1957-09-21           12
# 1054              Joel Coen  1954-11-29           11

# %%
dfStatsMovieByDirector.loc[33].birthdate
# Out:
# datetime.date(1899, 8, 13)

# %%
# other idea: instead of apply read column birthdate as datetime64 (NaT)
limit = 1000
dfStars = pd.read_json(f'http://localhost:8000/stars?limit={limit}', convert_dates=['birthdate'])
dfStars.set_index('id', inplace=True)
dfStars
# Out:
#                  name  birthdate
# id
# 1        Fred Astaire 1899-01-01
# 2       Lauren Bacall 1924-01-01
# 3     Brigitte Bardot 1934-01-01
# 4        John Belushi        NaT
# 6      Ingrid Bergman 1915-01-01
# ...               ...        ...
# 1480     Shelley Long        NaT
# 1484       Jon Lovitz 1957-01-01
# 1485        Myrna Loy 1905-01-01
# 1486     Sidney Lumet        NaT
# 1489       Paul Lynde 1926-01-01
#
# [1000 rows x 2 columns]

# %%
df
